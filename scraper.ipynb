# %%
import requests
import time

url = 'https://www.kayak.com'
r = requests.get(url)
layer1Cookies = r.cookies

url2 = url + '/s/horizon/flights/results/FlightSearchPoll'

origin_code = 'WAS'
origin_location = 'WASHINGTON'
destination_code = 'AMD'
destination_location = 'Ahmedabad'
depart_date = '2018-04-20'
return_date = '2018-04-27'

referer = 'https://www.kayak.com/flights/'+origin_code+'-'+destination_code+'/'+depart_date+'/'+return_date
headers = {
    'Host': 'www.kayak.com',
    'User-Agent': 'Chrome/63 (Macintosh; Intel Mac OS X 10.11; rv:57.0) Gecko/20100101 Firefox/57.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': referer,
    'Content-Type': 'application/x-www-form-urlencoded',
    'X-CSRF': 'kAqI1NgGh$DJnEUpiSDOWpdQXzlgAwG8EVOCd$gXO08-hpumC4oNpaOjz15GO_q9a5FdZPonpC2kF4CBYjEPh14',
    'X-RequestId': 'flights#frontdoor#Ag$s9g',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Length': '1094'
}
params = {
    'searchId':'',
    'poll':'true',
    'pollNumber':'0',
    'applyFilters':'true',
    'filterState':'',
    'useViewStateFilterState':'false',
    'pageNumber':'1',
    'append':'false',
    'pollingId':'593606',  #interesting. explore further
    'requestReason':'POLL',
    'isSecondPhase':'false',
    'textAndPageLocations':'bottom,right',
    'displayAdPageLocations':'none',
    'existingAds':'false',
    'activeLeg':'-1',
    'view':'list',
    'renderPlusMinusThreeFlex':'false',
    'renderAirlineStopsMatrix':'false',
    'renderFlexHeader':'true',
    'tab':'flights',
    'pageOrigin':'F..FD..M0',
    'src':'',
    'searchingAgain':'',
    'c2s':'',
    'po':'',
    'personality':'',
    'provider':'',
    'isMulticity':'false',
    'flex_category':'exact',
    'depart_date':'12/30/2017',
    'return_date':'01/31/2018',
    'oneway':'false',
    'origincode':'WAS',  #change accordingly
    'origin':'WAS', #change accordingly
    'origin_location':'Washington+(WAS)', #change accordingly
    'origin_code':'WAS/2279', #change accordingly
    'nearby_origin':'false',
    'destination':'LIM', #change accordingly
    'destination_location':'Lima', #change accordingly
    'destination_code':'LIM/2270', #change accordingly
    'nearby_destination':'false',
    'countrySearch':'false',
    'depart_date_canon':'2017-12-30', #change accordingly
    'return_date_canon':'2018-01-31', #change accordingly
    'travelers':'1',
    'adults':'1',
    'seniors':'0',
    'youth':'0',
    'child':'0',
    'seatInfant':'0',
    'lapInfant':'0',
    'cabin':'e',
    'cabinDisplayType':'Economy',
    'vertical':'flights',
    'url':'flights/WAS-LIM/2017-12-30/2018-01-31',
    'id':'',
    'navigateToResults':'false',
    'ajaxts':'',
    'scriptsMetadata':'',
    'stylesMetadata':'',
}


url3 = 'flights/'+origin_code+'-'+destination_code+'/'+depart_date+'/'+return_date

params1 = {
    'searchId':'',
    'poll':'true',
    'pollNumber':'0',
    'applyFilters':'true',
    'filterState':'',
    'useViewStateFilterState':'false',
    'pageNumber':'1',
    'append':'false',
    'pollingId':'593601',  #interesting. explore further
    'requestReason':'POLL',
    'isSecondPhase':'false',
    'textAndPageLocations':'bottom,right',
    'displayAdPageLocations':'none',
    'existingAds':'false',
    'activeLeg':'-1',
    'view':'list',
    'renderPlusMinusThreeFlex':'false',
    'renderAirlineStopsMatrix':'false',
    'renderFlexHeader':'true',
    'tab':'flights',
    'pageOrigin':'F..FD..M0',
    'src':'',
    'searchingAgain':'',
    'c2s':'',
    'po':'',
    'personality':'',
    'provider':'',
    'isMulticity':'false',
    'flex_category':'exact',
    'depart_date':depart_date,
    'return_date':return_date,
    'oneway':'false',
    'origincode':origin_code,  #change accordingly
    'origin':origin_code, #change accordingly
    'origin_location':origin_location, #change accordingly
    'origin_code':'', #change accordingly
    'nearby_origin':'false',
    'destination':destination_code, #change accordingly
    'destination_location':destination_location, #change accordingly
    'destination_code':'', #change accordingly
    'nearby_destination':'false',
    'countrySearch':'false',
    'depart_date_canon':depart_date, #change accordingly
    'return_date_canon':return_date, #change accordingly
    'travelers':'1',
    'adults':'1',
    'seniors':'0',
    'youth':'0',
    'child':'0',
    'seatInfant':'0',
    'lapInfant':'0',
    'cabin':'e',
    'cabinDisplayType':'Economy',
    'vertical':'flights',
    'url':url3,
    'id':'',
    'navigateToResults':'false',
    'ajaxts':'',
    'scriptsMetadata':'',
    'stylesMetadata':'',
}

next = requests.post(url2, headers = headers, data = params1, cookies = layer1Cookies)
next.json()
# Out:
# {'bufferedHTML': [],
#  'bufferedSVGs': ['<symbol id="common-booking-ticket-icon_O_tj_e_iP_fv"  viewBox="0 0 12 9" xmlns="http://www.w3.org/2000/svg">\n    <g fill="currentColor">\n        <path d="M8.72727273,1.96064815 C8.42618182,1.96064815 8.18181818,1.71024537 8.18181818,1.40046296 C8.18181818,1.09068056 8.42618182,0.840277778 8.72727273,0.840277778 C9.02836364,0.840277778 9.27272727,1.09068056 9.27272727,1.40046296 C9.27272727,1.71024537 9.02836364,1.96064815 8.72727273,1.96064815 M8.72727273,3.6412037 C8.42618182,3.6412037 8.18181818,3.39080093 8.18181818,3.08101852 C8.18181818,2.77123611 8.42618182,2.52083333 8.72727273,2.52083333 C9.02836364,2.52083333 9.27272727,2.77123611 9.27272727,3.08101852 C9.27272727,3.39080093 9.02836364,3.6412037 8.72727273,3.6412037 M8.72727273,5.32175926 C8.42618182,5.32175926 8.18181818,5.07135648 8.18181818,4.76157407 C8.18181818,4.45179167 8.42618182,4.20138889 8.72727273,4.20138889 C9.02836364,4.20138889 9.27272727,4.45179167 9.27272727,4.76157407 C9.27272727,5.07135648 9.02836364,5.32175926 8.72727273,5.32175926 M10.9090909,0 L1.09090909,0 C0.488727273,0 0,0.501925926 0,1.12037037 L0,5.04166667 C0,5.66011111 0.488727273,6.16203704 1.09090909,6.16203704 L10.9090909,6.16203704 C11.5112727,6.16203704 12,5.66011111 12,5.04166667 L12,1.12037037 C12,0.501925926 11.5112727,0 10.9090909,0"></path>\n        <path d="M0.818454545,8.07019583 C0.941181818,8.6763162 1.51881818,9.06508472 2.10845455,8.93960324 L10.3639091,6.72239028 L0.545727273,6.72239028 L0.818454545,8.07019583 Z" id="Fill-3"></path>\n    </g>\n</symbol>',
#   '<symbol id="common-booking-carry-on-bag_O_tj_e_iP_iK_w1_w0"  width="9" height="10" viewBox="0 0 9 10" xmlns="http://www.w3.org/2000/svg" fill="currentColor"><path d="
="16" height="16" viewBox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path fill="currentColor" d="M10.13 3.613a1.598 1.598 0 1 1 2.258 2.26 1.598 1.598 0 0 1-2.259-2.26m5.755 3.17L16 .69A.676.676 0 0 0 15.31 0L9.218.118a.932.932 0 0 0-.639.272L.333 8.637a1.136 1.136 0 0 0 0 1.606l5.425 5.425a1.138 1.138 0 0 0 1.607 0l8.248-8.246c.17-.17.266-.4.271-.64"/></symbol>'],
#  'bufferedScripts': ['R9.events.publish("flights.results.savedItems.update", {"presentation":null,"openDetails":{},"inlineTravelAudienceAdSlots":[],"tripsMap":{},"listSize":0,"expiryMessage":null,"savedSearchId":null});new R9.flights.results.scripts.FlightAboveHeaderContent("uviZ", {\n        "searchId": "vbDCJUO9mn",\n        "flexDialogLoaded": false,\n        "airlineMatrixLoaded": false\n    });new R9.common.kn.rp.Inline("inline-1");new R9.common.widgets.tip.ToolTip("Fh9k-tooltip-icon", {"presentation":null,"theme":"DEFAULT","phoenixRising":false,"target":"Fh9k-tooltip-icon","positionTarget":null,"content":"                            We think you\'ll like these flights based on their duration, price, number of stops and carrier type.                \\n    ","position":"top","fallbackPosition":null,"orientation":"middle","activation":"hover","subNameSpace":"","alwaysRendered":false,"color":"opaque","edgeOffset":8,"leftOffset":3,"closeOnBodyClick":true,"baseClass":"cooltip-component","delay":0,"closeDelay":0,"keepOpenOnContentHover":true,"extraClass":"Flights-Results-BestFlights-Tooltip drop-shadow-pr fee-assistant-design","isComponent":true,"size":"l"});new R9.flights.results.DetailsLink("V8_V-aria-details", {"presentation":null,"resultId":"58221d2c191f61294b0ed0a49ba745d3","leg":null,"useDetailsDialog":false,"openToRatesTable":false,"showOpenForAllTabs":false});$("#V8_V-info-leg-0-stops .dot").toolTip({color: "black"});new R9.flights.results.LegInfo("V8_V-info-leg-0", {"presentation":null,"legNumber":0,"resultId":"58221d2c191f61294b0ed0a49ba745d3","signature":"IADAMD1524261600000EY1301524348000000EY2882","hasSpecificLegCheckbox":false});$("#V8_V-info-leg-1-stops .dot").toolTip({color: "black"});new R9.flights.results.LegInfo("V8_V-info-leg-1", {"presentation":null,"legNumber":1,"resultId":"58221d2c191f61294b0ed0a49ba745d3","signature":"AMDIAD1524805200000EY2891524823200000EY1312","hasSpecificLegCheckbox":false});new R9.flights.results.PromotedBooking("V8_V-extra-info-hbo", {"presentation":null,"isDirectBooking":true,"providerCode":"EY"});new R9.common.widgets.tip.ToolTip("V8_V-price-int", {"presentation":null,"theme":"DEFAULT","phoenixRising":false,"target":"V8_V-price-int","positionTarget":"V8_V-price-int","content":"            <div id=\\"c4-ht\\" class=\\"Common-Booking-PriceBreakdownTooltip Common-Booking-PriceBreakdownTooltipV2 _w9 _w8\\">\\n        <div class=\\"_eY _eZ _w _G _kG _y _i7 _d2 _i8 _tS\\">\\n            Price Breakdown        </div>\\n\\n        <div class=\\"_cV _jt _i7 _i8\\" role=\\"list\\">\\n            <div class=\\"_de _w3 _w2 _dd\\" role=\\"group\\">\\n                                    <div class=\\"_de _nF _nV _of _x _cQ _cP _dd _tX _v _ho\\" role=\\"listitem\\">\\n                        <div class=\\"_rE _4\\">\\n                            <svg class=\\"_O _tj _e _iP _fv\\" viewBox=\\"0 0 12 9\\" xmlns=\\"http://www.w3.org/2000/svg\\"><use xlink:href=\\"#common-booking-ticket-icon_O_tj_e_iP_fv\\"/></svg>                        </div>\\n                        <div class=\\"_rE\\">\\n                            Ticket price:                        </div>\\n                        <div class=\\"_wX _ey _wW _rE _cQ _cP\\">\\n                            $985\\n                        </div>\\n                    </div>\\n                \\n                                    <div class=\\"_de _nF _nV _of _x _cQ _cP _dd _tX _v _ho\\" role=\\"listitem\\">\\n                        <div class=\\"_rE _4\\">\\n                            <svg class=\\"_O _tj _e _iP _iK _w1 _w0\\" width=\\"9\\" height=\\"10\\" viewBox=\\"0 0 9 10\\" xmlns=\\"http://www.w3.org/2000/svg\\" fill=\\"currentColor\\"><use xlink:href=\\"#common-booking-carry-on-bag_O_tj_e_iP_iK_w1_w0\\"/></svg>                        </div>\\n                        <div class=\\"_rE\\">\\n                            Carry-on bag:                        </div>\\n                                                    <div class=\\"_wX _ey _wW  ...
#  'clientTemplates': [],
#  'content': '<div id="savedResultsListContainer" data-ajax-replace>\n</div>\n<div id="aboveHeaderContainer" class="aboveHeaderContainer " data-ajax-replace>\n<div id="uviZ" class="Flights-Results-FlightAboveHeaderContent FlightAboveHeaderContent">\n<div class="flexMatrixWrapper" aria-expanded="false">\n</div>\n<div class="airlineWrapper" aria-expanded="false">\n</div>\n</div>\n</div>\n<div id="aboveResultsContainer" class="aboveResultsContainer" data-ajax-replace>\n<div id="DD2w" class="Flights-Results-FlightAboveResultsContent">\n</div>\n</div>\n<div id="searchResultsList" class="Base-Results-ResultsList Flights-Results-FlightResultsList">\n<div id="vbDCJUO9mn-1">\n<div\nid="inline-1"\nclass="Common-Kn-Rp-Inline flights phoenix-rising clearfix type-provider"\nonclick="R9.events.publish(\'ecommerce.track\', {event: \'inline.ad\'});"\nrole="link"\naria-label="Advertisement from Orbitz.com: Orbitz Flight Deals – Price Guarantee Plus earn Orbitz Rewards"\ntabindex="0" tabbable>\n<nav class="aria-controls">\n<a href="javascript:void(0)" id="inline-1-skip">Skip this item</a>\n</nav>\n<div id="c7miH" class="Common-Kn-Rp-FlightInline simple no-price" onclick="window.open(\'https://www.kayak.com/s/clickthrough.jsp?ctyp=InlineOpaqueAdBooking&ptyp=F&orig=F..RP..M1&octid=&plid=9923392&cpnid=7032967&pid=OrbitzFlight2_FIOAD_US&prv=OrbitzFlight2_FIOAD_US&srch=vbDCJUO9mn&ploc=US&displayRail=Rslt&rank=1&adtype=inline&prc=&xpExt=&aidExt=&lid=OrbitzFlight2_FIOAD_US-vbDCJUO9mn&qorig=Airport:WAS&qdest=Airport:AMD&qstart=1524196800000&qend=1524801600000&qtravelers=1&qrooms=0&qow=false&qfcc=e&qdctid=29732&qdac=AMD&qshour=-1&qehour=-1&resid=&bookid=&seekProv=&qns=false&qnearby=0&qnearbyo=false&qnearbyd=false&qadults=1&qcages=&qinfantseat=0&qinfantlap=0&qsenior=0&pgNum=1&copyId=0&iar=1&stid=508465286&ah=9LrahXs_jpNSSnJQdM_HIpuIINrlsbBN3Ws_09lB7sQ&pj=JDxB01Ia1VIqX0oCDiqO5w==\')">\n<div class="content-col ">\n<div class="icon">\n<img alt="Orbitz.com" src="/kimg/logos/4bc1908f80fcc4ce.png" />\n</div>\n<div class="content">\n<div class="inlineAdHeadline">Orbitz Flight Deals – Price Guarantee</div>\n<div class="inlineAdDescription no-options">\n<span>Plus earn Orbitz Rewards</span>\n</div>\n<div class="inlineAdFooter clean">\n<span>Orbitz.com | </span> <span class="sponsoredTag">Sponsored</span>\n</div>\n</div>\n</div>\n<div class="price-col inlineAdPriceColumn no-price right-alignment">\n<div class="inlineAdSelect">\n<div class="bookitselect">\n<a class="ui-button Button-Gradient" href="javascript:void(0)" target="" rel="nofollow"\nonclick=""\naria-label="View deal from Orbitz.com">\n<div class="view-deal">\nView Deal </div>\n</a>\n</div>\n</div>\n</div>\n</div>\n</div>\n<div class="Flights-Results-BestFlights phoenix-rising withChrome" id="Fh9k">\n<div class="best-flights-list">\n<div class="best-flights-border-container"></div>\n<div class="best-flights-header">\n<span class="title">\nBest Flights\n</span>\n<span id="Fh9k-tooltip-icon" class="information">\n&#9432;\n</span>\n</div>\n<div id="V8_V"\nclass="Base-Results-HorizonResult Flights-Results-FlightResultItem phoenix-rising "\npage-idx="0"\ndata-resultId="58221d2c191f61294b0ed0a49ba745d3"\ntabindex="0"\naria-label="Best flight number 1: $985 from KAYAK."\naria-describedby="V8_V-describedby"\ntabbable\n>\n<nav class="aria-controls">\n<p id="V8_V-describedby" style="display: none"> Leg 1: Provided by Etihad Airways. Departs from Washington, DC - Dulles Intl on 4/20 at 10:10 pm, lands in Ahmedabad, India - Ahmedabad on 4/22 at 3:15 am. 1 stop (AUH). Total duration: 19h 35m. Leg 2: Provided by Etihad Airways. Departs from Ahmedabad, India - Ahmedabad on 4/27 at 5:05 am, lands in Washington, DC - Dulles Intl on 4/27 at 4:40 pm. 1 stop (AUH). Total duration: 21h 05m. We think you\'ll like these flights based on their duration, price, number of stops and carrier type.</p>\n<a href="javascript:void(0)" id="V8_V-skip">Go to next result</a>\n<a href="#V8_V-price">Go to price</a>\n<a href="#V8_V-info">Go to  ...
#  'globals': {'analytics': {'pixelContext': {'advancedBookingWindow': 49,
#     'cabinClass': 'economy',
#     'depart_date': '2018-04-20',
#     'destination': {'cityId': '29732',
#      'cityName': 'Ahmedabad',
#      'country': 'India',
#      'region': 'Gujarat'},
#     'destinationCode': 'AMD',
#     'isLoggedIn': False,
#     'legs': 2,
#     'lengthOfStay': 7,
#     'obfuscatedSessionId': 'SUV6NAx7QTglyWHZ9IYQZcVFOQU',
#     'obfuscatedTrackingCookie': 'cNZNmybSrjXukfQYnKlQePR9ftU',
#     'origin': {'cityId': '2279',
#      'cityName': 'Washington',
#      'country': 'United States',
#      'region': 'District of Columbia'},
#     'originCode': 'WAS',
#     'return_date': '2018-04-27',
#     'roundTrip': True,
#     'searchId': 'vbDCJUO9mn',
#     'site_currency': 'USD',
#     'travelers': 1,
#     'travelersAdults': 1,
#     'travelersChildren': 0,
#     'travelersSeniors': 0,
#     'userScore': '0',
#     'userValuationScore': '208'}},
#   'formtoken': 'tYD6j1M74pA$wk3l2pqj60pFl6kYZxqwRoM6KhCGSIM-07pZRN2TizlxKRupMownutmZ8eaLvYAcwS3por6zwRU'},
#  'react': None,
#  'scripts': ['https://a1.r9cdn.net/res/js/horizon/combined-30.js?v=bcb8a688f81f772db05693c5046d8ffeaeac4b2a-phoenix-rising'],
#  'scriptsMetadata': '10E10M1Cw1M7g20I4C4g2g9Q26GU1gVwCQG10I29g=',
#  'styles': ['https://a1.r9cdn.net/res/css/horizon/combined-36.css?v=725404135966c8236e1409d3b31bd25166ca2382-phoenix-rising'],
#  'stylesMetadata': '10B39gY23i33B5CgC6gC7Q47JkBCtTTCYC1Iw==',
#  'version': 'R405d'}
